# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/ml0602/blob/main/cifar10_gap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets.cifar10 import load_data
(x_train, y_train), (x_test, y_test) = load_data()

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
names = [
    "airplane",										
    "automobile",										
    "bird",										
    "cat",										
    "deer",										
    "dog",										
    "frog",										
    "horse",										
    "ship",										
    "truck"
]

# %%
# mnist: (60000, ) [5, 2, 1, 0]
import matplotlib.pyplot as plt
import random
idx = random.randint(0, 49999)
ans = y_train[idx][0]
print(names[ans])
plt.imshow(x_train[idx])
# Out:
# airplane

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
layers = [
    # 3 * 3 * 3(一個) * 64 + 64(bias) = 1792
    Conv2D(64, 3, activation="relu", padding="same", input_shape=(32, 32, 3)),
    MaxPooling2D(),
    # 3 * 3 * 64(一個) * 128 + 128(bias) = 73856
    Conv2D(128, 3, activation="relu", padding="same"),
    MaxPooling2D(),
    Conv2D(256, 3, activation="relu", padding="same"),
    GlobalAveragePooling2D(),
    Dense(10, activation="softmax")
]
model = Sequential(layers)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 373,386
# Trainable params: 373,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
model.compile(loss=SparseCategoricalCrossentropy(),
              optimizer=Adam(),
              metrics=["accuracy"])

# %%
x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# validation_split: 切出一些驗證資料來做驗證(0.1: 54000筆資料訓練)
# epochs: 看幾輪(10輪: 54000 * 10)
# batch_size: 看了多少筆再做一次梯度調整(看圖片大小, 圖片小(20*20):200, 圖片大(200*200):20)
# 200batch, 10epoch: 54000 * 10 / 200 -> 2700(梯度調整)
# verbose: 0(無聲) 1(最詳細) 2(沒有進度條)
callbacks = [
    EarlyStopping(patience=5, restore_best_weights=True),
    ModelCheckpoint("cnn.h5", save_best_only=True)
]
# h5: https://www.hdfgroup.org/downloads/hdfview/
model.fit(x_train_norm,
          y_train,
          validation_split=0.1,
          epochs=100,
          batch_size=200,
          verbose=2,
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 225/225 - 4s - loss: 1.8492 - accuracy: 0.3082 - val_loss: 1.6106 - val_accuracy: 0.4016
# Epoch 2/100
# 225/225 - 3s - loss: 1.5528 - accuracy: 0.4340 - val_loss: 1.4445 - val_accuracy: 0.4834
# Epoch 3/100
# 225/225 - 3s - loss: 1.4295 - accuracy: 0.4838 - val_loss: 1.3655 - val_accuracy: 0.4948
# Epoch 4/100
# 225/225 - 3s - loss: 1.3414 - accuracy: 0.5183 - val_loss: 1.3065 - val_accuracy: 0.5272
# Epoch 5/100
# 225/225 - 3s - loss: 1.2811 - accuracy: 0.5430 - val_loss: 1.2648 - val_accuracy: 0.5340
# Epoch 6/100
# 225/225 - 3s - loss: 1.2125 - accuracy: 0.5688 - val_loss: 1.2015 - val_accuracy: 0.5728
# Epoch 7/100
# 225/225 - 3s - loss: 1.1676 - accuracy: 0.5842 - val_loss: 1.1434 - val_accuracy: 0.5914
# Epoch 8/100
# 225/225 - 3s - loss: 1.1211 - accuracy: 0.6016 - val_loss: 1.0989 - val_accuracy: 0.6050
# Epoch 9/100
# 225/225 - 3s - loss: 1.0762 - accuracy: 0.6182 - val_loss: 1.0709 - val_accuracy: 0.6236
# Epoch 10/100
# 225/225 - 3s - loss: 1.0360 - accuracy: 0.6358 - val_loss: 1.0049 - val_accuracy: 0.6486
# Epoch 11/100
# 225/225 - 3s - loss: 1.0150 - accuracy: 0.6434 - val_loss: 1.0341 - val_accuracy: 0.6368
# Epoch 12/100
# 225/225 - 3s - loss: 0.9777 - accuracy: 0.6569 - val_loss: 0.9965 - val_accuracy: 0.6492
# Epoch 13/100
# 225/225 - 3s - loss: 0.9601 - accuracy: 0.6624 - val_loss: 0.9746 - val_accuracy: 0.6612
# Epoch 14/100
# 225/225 - 3s - loss: 0.9326 - accuracy: 0.6710 - val_loss: 0.9702 - val_accuracy: 0.6590
# Epoch 15/100
# 225/225 - 3s - loss: 0.9176 - accuracy: 0.6779 - val_loss: 0.9059 - val_accuracy: 0.6754
# Epoch 16/100
# 225/225 - 3s - loss: 0.8871 - accuracy: 0.6892 - val_loss: 0.9488 - val_accuracy: 0.6702
# Epoch 17/100
# 225/225 - 3s - loss: 0.8725 - accuracy: 0.6922 - val_loss: 0.8830 - val_accuracy: 0.6878
# Epoch 18/100
# 225/225 - 3s - loss: 0.8545 - accuracy: 0.7010 - val_loss: 0.8816 - val_accuracy: 0.6870
# Epoch 19/100
# 225/225 - 3s - loss: 0.8347 - accuracy: 0.7100 - val_loss: 0.8801 - val_accuracy: 0.6930
# Epoch 20/100
# 225/225 - 3s - loss: 0.8133 - accuracy: 0.7153 - val_loss: 0.8430 - val_accuracy: 0.7030
# Epoch 21/100
# 225/225 - 3s - loss: 0.8008 - accuracy: 0.7183 - val_loss: 0.8185 - val_accuracy: 0.7114
# Epoch 22/100
# 225/225 - 3s - loss: 0.7896 - accuracy: 0.7222 - val_loss: 0.8431 - val_accuracy: 0.7040
# Epoch 23/100
# 225/225 - 3s - loss: 0.7703 - accuracy: 0.7291 - val_loss: 0.8306 - val_accuracy: 0.7060
# Epoch 24/100
# 225/225 - 3s - loss: 0.7533 - accuracy: 0.7377 - val_loss: 0.8240 - val_accuracy: 0.7066
# Epoch 25/100
# 225/225 - 3s - loss: 0.7404 - accuracy: 0.7408 - val_loss: 0.7726 - val_accuracy: 0.7356
# Epoch 26/100
# 225/225 - 3s - loss: 0.7229 - accuracy: 0.7483 - val_loss: 0.8096 - val_accuracy: 0.7196
# Epoch 27/100
# 225/225 - 3s - loss: 0.7140 - accuracy: 0.7510 - val_loss: 0.7998 - val_accuracy: 0.7188
# Epoch 28/100
# 225/225 - 3s - loss: 0.6975 - accuracy: 0.7567 - val_loss: 0.7590 - val_accuracy: 0.7358
# Epoch 29/100
# 225/225 - 3s - loss: 0.6884 - accuracy: 0.7595 - val_loss: 0.7733 - val_accuracy: 0.7272
# Epoch 30/100
# 225/225 - 3s - loss: 0.6799 - accuracy: 0.7646 - val_loss: 0.7570 - val_accuracy: 0.7324
# Epoch 31/100
# 225/225 - 3s - loss: 0.6639 - accuracy: 0.7671 - val_loss: 0.7360 - val_accuracy: 0.7474
# Epoch 32/100
# 225/225 - 3s - loss: 0.6487 - accuracy: 0.7754 - val_loss: 0.7420 - val_accuracy: 0.7464
# Epoch 33/100
# 225/225 - 3s - loss: 0.6390 - accuracy: 0.7780 - val_loss: 0.7489 - val_accuracy: 0.7362
# Epoch 34/100
# 225/225 - 3s - loss: 0.6244 - accuracy: 0.7843 - val_loss: 0.7031 - val_accuracy: 0.7548
# Epoch 35/100
# 225/225 - 3s - loss: 0.6099 - accuracy: 0.7877 - val_loss: 0.7056 - val_accuracy: 0.7560
# Epoch 36/100
# 225/225 - 3s - loss: 0.6035 - accuracy: 0.7894 - val_loss: 0.7561 - val_accuracy: 0.7334
# Epoch 37/100
# 225/225 - 3s - loss: 0.5877 - accuracy: 0.7966 - val_loss: 0.6932 - val_accuracy: 0.7604
# Epoch 38/100
# 225/225 - 3s - loss: 0.5696 - accuracy: 0.8027 - val_loss: 0.6955 - val_accuracy: 0.7632
# Epoch 39/100
# 225/225 - 3s - loss: 0.5727 - accuracy: 0.8020 - val_loss: 0.6776 - val_accuracy: 0.7680
# Epoch 40/100
# 225/225 - 3s - loss: 0.5602 - accuracy: 0.8057 - val_loss: 0.6953 - val_accuracy: 0.7656
# Epoch 41/100
# 225/225 - 3s - loss: 0.5430 - accuracy: 0.8122 - val_loss: 0.6796 - val_accuracy: 0.7616
# Epoch 42/100
# 225/225 - 3s - loss: 0.5420 - accuracy: 0.8118 - val_loss: 0.6634 - val_accuracy: 0.7724
# Epoch 43/100
# 225/225 - 3s - loss: 0.5179 - accuracy: 0.8211 - val_loss: 0.6749 - val_accuracy: 0.7630
# Epoch 44/100
# 225/225 - 3s - loss: 0.5099 - accuracy: 0.8242 - val_loss: 0.7038 - val_accuracy: 0.7586
# Epoch 45/100
# 225/225 - 3s - loss: 0.5093 - accuracy: 0.8233 - val_loss: 0.6653 - val_accuracy: 0.7734
# Epoch 46/100
# 225/225 - 3s - loss: 0.4956 - accuracy: 0.8286 - val_loss: 0.6803 - val_accuracy: 0.7724
# Epoch 47/100
# 225/225 - 3s - loss: 0.4853 - accuracy: 0.8332 - val_loss: 0.6584 - val_accuracy: 0.7748
# Epoch 48/100
# 225/225 - 3s - loss: 0.4751 - accuracy: 0.8343 - val_loss: 0.6554 - val_accuracy: 0.7804
# Epoch 49/100
# 225/225 - 3s - loss: 0.4712 - accuracy: 0.8380 - val_loss: 0.6554 - val_accuracy: 0.7782
# Epoch 50/100
# 225/225 - 3s - loss: 0.4507 - accuracy: 0.8446 - val_loss: 0.6967 - val_accuracy: 0.7636
# Epoch 51/100
# 225/225 - 3s - loss: 0.4542 - accuracy: 0.8430 - val_loss: 0.6744 - val_accuracy: 0.7712
# Epoch 52/100
# 225/225 - 3s - loss: 0.4336 - accuracy: 0.8502 - val_loss: 0.6530 - val_accuracy: 0.7850
# Epoch 53/100
# 225/225 - 3s - loss: 0.4257 - accuracy: 0.8523 - val_loss: 0.6689 - val_accuracy: 0.7792
# Epoch 54/100
# 225/225 - 3s - loss: 0.4209 - accuracy: 0.8542 - val_loss: 0.6531 - val_accuracy: 0.7802
# Epoch 55/100
# 225/225 - 3s - loss: 0.4175 - accuracy: 0.8554 - val_loss: 0.6693 - val_accuracy: 0.7778
# Epoch 56/100
# 225/225 - 3s - loss: 0.4014 - accuracy: 0.8604 - val_loss: 0.6526 - val_accuracy: 0.7862
# Epoch 57/100
# 225/225 - 3s - loss: 0.4034 - accuracy: 0.8608 - val_loss: 0.6627 - val_accuracy: 0.7768
# Epoch 58/100
# 225/225 - 3s - loss: 0.3837 - accuracy: 0.8682 - val_loss: 0.6717 - val_accuracy: 0.7806
# Epoch 59/100
# 225/225 - 3s - loss: 0.3765 - accuracy: 0.8690 - val_loss: 0.6879 - val_accuracy: 0.7780
# Epoch 60/100
# 225/225 - 3s - loss: 0.3665 - accuracy: 0.8728 - val_loss: 0.6333 - val_accuracy: 0.7872
# Epoch 61/100
# 225/225 - 3s - loss: 0.3597 - accuracy: 0.8754 - val_loss: 0.6537 - val_accuracy: 0.7874
# Epoch 62/100
# 225/225 - 3s - loss: 0.3521 - accuracy: 0.8788 - val_loss: 0.6651 - val_accuracy: 0.7860
# Epoch 63/100
# 225/225 - 3s - loss: 0.3450 - accuracy: 0.8808 - val_loss: 0.6425 - val_accuracy: 0.7890
# Epoch 64/100
# 225/225 - 3s - loss: 0.3305 - accuracy: 0.8851 - val_loss: 0.6644 - val_accuracy: 0.7854
# Epoch 65/100
# 225/225 - 3s - loss: 0.3304 - accuracy: 0.8869 - val_loss: 0.6520 - val_accuracy: 0.7854

# %%
model.evaluate(x_test_norm, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6509 - accuracy: 0.7820
# [0.6508806347846985, 0.7820000052452087]

# %%
pre = model.predict_classes(x_test_norm)
print(y_test.shape)
print(pre.shape)
# -1: 叫他幫你算 10000 * 1 = -1(?)
y_test_r = y_test.reshape(-1)
print(y_test_r.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# (10000, 1)
# (10000,)
# (10000,)

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
# predict_proba -> predict
# predict -> predict_classes
# 只要在tensorflow: 就帶one-hot y_test_cat
# 不在: 帶原本 y_test
pre = model.predict_classes(x_test_norm)
mat = confusion_matrix(y_test_r, pre)
pd.DataFrame(mat, 
             columns=["{}(預測)".format(names[i]) for i in range(10)],
             index=["{}(正確)".format(names[i]) for i in range(10)])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#                 airplane(預測)  automobile(預測)  ...  ship(預測)  truck(預測)
# airplane(正確)             835              18  ...        34         32
# automobile(正確)            17             872  ...        13         81
# bird(正確)                  66               4  ...         2         12
# cat(正確)                   14              11  ...         5          8
# deer(正確)                  16               2  ...         5          2
# dog(正確)                    9               7  ...         2          8
# frog(正確)                   4               2  ...         6          4
# horse(正確)                 15               1  ...         0         12
# ship(正確)                  82              24  ...       822         32
# truck(正確)                 26              48  ...         9        883
#
# [10 rows x 10 columns]

# %%
import numpy as np
idx = np.nonzero(pre != y_test_r)[0]
idx = idx[:200]
# np.nonzero([[0, 2, 0], [0, 0, 3]])
false_pre = pre[idx]
false_label = y_test_r[idx] 
false_img = x_test[idx]

plt.figure(figsize=(14, 42))
width = 10
height = len(idx) // width + 1
for i in range(len(false_img)):
    plt.subplot(height, width, i+1)
    title = "[P]:{}\n[O]:{}".format(names[false_pre[i]], names[false_label[i]])
    plt.title(title)
    plt.axis("off")
    plt.imshow(false_img[i])

# %%
import requests
from PIL import Image
url = input("輸入網址:")
response = requests.get(url, verify=False, stream=True)
img = Image.open(response.raw)
img = img.resize((32, 32)).convert("RGB")
img_np = np.array(img)
img_norm = np.array([img_np]) / 255
pre = model.predict(img_norm)[0]
for n, p in zip(names, pre):
    print(n, "的機率:", round(p, 3))
plt.imshow(img)
# Out:
# 輸入網址:http://pic.pimg.tw/sheng1378/1383219879-2598159896.jpg
# airplane 的機率: 0.0
# automobile 的機率: 0.0
# bird 的機率: 0.428
# cat 的機率: 0.052
# deer 的機率: 0.077
# dog 的機率: 0.328
# frog 的機率: 0.05
# horse 的機率: 0.047
# ship 的機率: 0.0
# truck 的機率: 0.016
